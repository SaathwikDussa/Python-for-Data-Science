# %%
#import
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/SAI SAATHWIK DUSSA/OneDrive/Desktop/ass/dataset_project1/Sales.csv")

# %%
df
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity Ordered  9697 non-null   object
#  3   Price Each        9697 non-null   object
#  4   Order Date        9697 non-null   object
#  5   Purchase Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %%
df.shape
# Out:
# (9723, 6)

# %% [markdown]
# ####                                             DATA CLEANING
#
#
#
#
# ###             Here we see that whole rows are null values, so drop all the rows containing null.

# %%
df.isna().sum()
# Out:
# Order ID            26
# Product             26
# Quantity Ordered    26
# Price Each          26
# Order Date          26
# Purchase Address    26
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (9697, 6)

# %%
df[df["Quantity Ordered"].str[0:3]=='Qua']
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 1073  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1102  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1194  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1897  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2463  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3115  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3247  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3612  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3623  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 4901  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 5593  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 6506  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 7544  Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...

# %%
df=df[df["Quantity Ordered"].str[0:3]!='Qua']

# %%
df[df["Quantity Ordered"].str[0:3]=='Qua']
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
df['Quantity Ordered'] = df['Quantity Ordered'].astype('int32')
# Out:
# C:\Users\SAI SAATHWIK DUSSA\AppData\Local\Temp\ipykernel_13236\3426174855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Quantity Ordered'] = df['Quantity Ordered'].astype('int32')

# %%
df['Quantity Ordered'].dtype
# Out:
# dtype('int32')

# %%
df['Price Each'] = pd.to_numeric(df['Price Each'])
# Out:
# C:\Users\SAI SAATHWIK DUSSA\AppData\Local\Temp\ipykernel_13236\3382779315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price Each'] = pd.to_numeric(df['Price Each'])

# %%
df['Price Each'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #                        1)                    Sales for each product

# %%
df["sales"]= df["Quantity Ordered"] * df["Price Each"]
# Out:
# C:\Users\SAI SAATHWIK DUSSA\AppData\Local\Temp\ipykernel_13236\1839818637.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["sales"]= df["Quantity Ordered"] * df["Price Each"]

# %%
df["sales"]
# Out:
# 0       700.00
# 1        14.95
# 2        23.98
# 3       149.99
# 4        11.99
#          ...
# 9718    109.99
# 9719    149.99
# 9720    999.99
# 9721      5.98
# 9722    600.00
# Name: sales, Length: 9681, dtype: float64

# %%
df.head(10)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   141234                      iPhone                 1      700.00
# 1   141235    Lightning Charging Cable                 1       14.95
# 2   141236            Wired Headphones                 2       11.99
# 3   141237            27in FHD Monitor                 1      149.99
# 4   141238            Wired Headphones                 1       11.99
# 5   141239      AAA Batteries (4-pack)                 1        2.99
# 6   141240      27in 4K Gaming Monitor                 1      389.99
# 7   141241        USB-C Charging Cable                 1       11.95
# 8   141242  Bose SoundSport Headphones                 1       99.99
# 9   141243    Apple Airpods Headphones                 1      150.00
#
#        Order Date                         Purchase Address   sales
# 0  01/22/19 21:25          944 Walnut St, Boston, MA 02215  700.00
# 1  01/28/19 14:15         185 Maple St, Portland, OR 97035   14.95
# ...

# %%
df.groupby("Product")['sales'].sum().round()
# Out:
# Product
# 20in Monitor                   23648.0
# 27in 4K Gaming Monitor        121677.0
# 27in FHD Monitor               62846.0
# 34in Ultrawide Monitor        119317.0
# AA Batteries (4-pack)           5472.0
# AAA Batteries (4-pack)          4772.0
# Apple Airpods Headphones      122100.0
# Bose SoundSport Headphones     65893.0
# Flatscreen TV                  72900.0
# Google Phone                  190800.0
# LG Dryer                       23400.0
# LG Washing Machine             25200.0
# Lightning Charging Cable       17207.0
# Macbook Pro Laptop            399500.0
# ThinkPad Laptop               216998.0
# USB-C Charging Cable           15344.0
# Vareebadd Phone                50000.0
# Wired Headphones               12961.0
# iPhone                        265300.0
# Name: sales, dtype: float64

# %%
eachproduct=df.groupby("Product")['sales'].sum().round()

# %%
eachproduct.sort_values(ascending=False)
# Out:
# Product
# Macbook Pro Laptop            399500.0
# iPhone                        265300.0
# ThinkPad Laptop               216998.0
# Google Phone                  190800.0
# Apple Airpods Headphones      122100.0
# 27in 4K Gaming Monitor        121677.0
# 34in Ultrawide Monitor        119317.0
# Flatscreen TV                  72900.0
# Bose SoundSport Headphones     65893.0
# 27in FHD Monitor               62846.0
# Vareebadd Phone                50000.0
# LG Washing Machine             25200.0
# 20in Monitor                   23648.0
# LG Dryer                       23400.0
# Lightning Charging Cable       17207.0
# USB-C Charging Cable           15344.0
# Wired Headphones               12961.0
# AA Batteries (4-pack)           5472.0
# AAA Batteries (4-pack)          4772.0
# Name: sales, dtype: float64

# %% [markdown]
# #                                    Add columns named city and day

# %%
df['Purchase Address'][0].split(',')[1].strip()
# Out:
# 'Boston'

# %%
df['city']=df["Purchase Address"].apply(lambda x:x.split(',')[1].strip())
# Out:
# C:\Users\SAI SAATHWIK DUSSA\AppData\Local\Temp\ipykernel_13236\3403943906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city']=df["Purchase Address"].apply(lambda x:x.split(',')[1].strip())

# %%
df
# Out:
#      Order ID                   Product  Quantity Ordered  Price Each  \
# 0      141234                    iPhone                 1      700.00
# 1      141235  Lightning Charging Cable                 1       14.95
# 2      141236          Wired Headphones                 2       11.99
# 3      141237          27in FHD Monitor                 1      149.99
# 4      141238          Wired Headphones                 1       11.99
# ...       ...                       ...               ...         ...
# 9718   150497              20in Monitor                 1      109.99
# 9719   150498          27in FHD Monitor                 1      149.99
# 9720   150499           ThinkPad Laptop                 1      999.99
# 9721   150500    AAA Batteries (4-pack)                 2        2.99
# 9722   150501              Google Phone                 1      600.00
#
#           Order Date                       Purchase Address   sales  \
# ...

# %%
df['day']=df["Order Date"].str[3:5]
# Out:
# C:\Users\SAI SAATHWIK DUSSA\AppData\Local\Temp\ipykernel_13236\4283050765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day']=df["Order Date"].str[3:5]

# %%
df
# Out:
#      Order ID                   Product  Quantity Ordered  Price Each  \
# 0      141234                    iPhone                 1      700.00
# 1      141235  Lightning Charging Cable                 1       14.95
# 2      141236          Wired Headphones                 2       11.99
# 3      141237          27in FHD Monitor                 1      149.99
# 4      141238          Wired Headphones                 1       11.99
# ...       ...                       ...               ...         ...
# 9718   150497              20in Monitor                 1      109.99
# 9719   150498          27in FHD Monitor                 1      149.99
# 9720   150499           ThinkPad Laptop                 1      999.99
# 9721   150500    AAA Batteries (4-pack)                 2        2.99
# 9722   150501              Google Phone                 1      600.00
#
#           Order Date                       Purchase Address   sales  \
# ...

# %%
df['day'] = pd.to_numeric(df['day'])
# Out:
# C:\Users\SAI SAATHWIK DUSSA\AppData\Local\Temp\ipykernel_11388\3755447499.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day'] = pd.to_numeric(df['day'])

# %%
df['day'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# #                      2) Average sales for each product per day

# %%
df.groupby(['day','Product']).mean(['sales'])
# Out:
#                             Quantity Ordered  Price Each        sales
# day Product
# 01  20in Monitor                    1.000000      109.99   109.990000
#     27in 4K Gaming Monitor          1.000000      389.99   389.990000
#     27in FHD Monitor                1.000000      149.99   149.990000
#     34in Ultrawide Monitor          1.000000      379.99   379.990000
#     AA Batteries (4-pack)           1.307692        3.84     5.021538
# ...                                      ...         ...          ...
# 31  ThinkPad Laptop                 1.111111      999.99  1111.100000
#     USB-C Charging Cable            1.272727       11.95    15.209091
#     Vareebadd Phone                 1.000000      400.00   400.000000
#     Wired Headphones                1.034483       11.99    12.403448
#     iPhone                          1.000000      700.00   700.000000
#
# [572 rows x 3 columns]

# %% [markdown]
# #                       3)         Which products are sold the most

# %%
df
# Out:
#      Order ID                   Product  Quantity Ordered  Price Each  \
# 0      141234                    iPhone                 1      700.00
# 1      141235  Lightning Charging Cable                 1       14.95
# 2      141236          Wired Headphones                 2       11.99
# 3      141237          27in FHD Monitor                 1      149.99
# 4      141238          Wired Headphones                 1       11.99
# ...       ...                       ...               ...         ...
# 9718   150497              20in Monitor                 1      109.99
# 9719   150498          27in FHD Monitor                 1      149.99
# 9720   150499           ThinkPad Laptop                 1      999.99
# 9721   150500    AAA Batteries (4-pack)                 2        2.99
# 9722   150501              Google Phone                 1      600.00
#
#           Order Date                       Purchase Address   sales  \
# ...

# %%
########                                       USB-C Charging Cable is sold most.

# %%
df['Product'].value_counts()
# Out:
# USB-C Charging Cable          1171
# AAA Batteries (4-pack)        1082
# Lightning Charging Cable      1068
# AA Batteries (4-pack)         1039
# Wired Headphones              1005
# Apple Airpods Headphones       809
# Bose SoundSport Headphones     656
# 27in FHD Monitor               418
# iPhone                         379
# Google Phone                   317
# 34in Ultrawide Monitor         313
# 27in 4K Gaming Monitor         312
# Flatscreen TV                  243
# Macbook Pro Laptop             235
# ThinkPad Laptop                216
# 20in Monitor                   213
# Vareebadd Phone                124
# LG Washing Machine              42
# LG Dryer                        39
# Name: Product, dtype: int64

# %%
df['Product'].value_counts().index
# Out:
# Index(['USB-C Charging Cable', 'AAA Batteries (4-pack)',
#        'Lightning Charging Cable', 'AA Batteries (4-pack)', 'Wired Headphones',
#        'Apple Airpods Headphones', 'Bose SoundSport Headphones',
#        '27in FHD Monitor', 'iPhone', 'Google Phone', '34in Ultrawide Monitor',
#        '27in 4K Gaming Monitor', 'Flatscreen TV', 'Macbook Pro Laptop',
#        'ThinkPad Laptop', '20in Monitor', 'Vareebadd Phone',
#        'LG Washing Machine', 'LG Dryer'],
#       dtype='object')

# %%
df['Product'].value_counts().values
# Out:
# array([1171, 1082, 1068, 1039, 1005,  809,  656,  418,  379,  317,  313,
#         312,  243,  235,  216,  213,  124,   42,   39], dtype=int64)

# %% [markdown]
# #                                           DATA VISUALIZATION

# %% [markdown]
# #                          4)         product most sold

# %%
plt.figure(figsize=(6,6),dpi=100)
plt.title("MOST SOLD")
plt.plot(df['Product'].value_counts().index[:10],df['Product'].value_counts().values[:10])
plt.bar(df['Product'].value_counts().index[:10],df['Product'].value_counts().values[:10])
plt.xlabel("Product")
plt.ylabel("Quantity")
plt.grid()
plt.xticks(rotation=90);

# %% [markdown]
# #                             5)    city with highest sales

# %%
df
# Out:
#      Order ID                   Product  Quantity Ordered  Price Each  \
# 0      141234                    iPhone                 1      700.00
# 1      141235  Lightning Charging Cable                 1       14.95
# 2      141236          Wired Headphones                 2       11.99
# 3      141237          27in FHD Monitor                 1      149.99
# 4      141238          Wired Headphones                 1       11.99
# ...       ...                       ...               ...         ...
# 9718   150497              20in Monitor                 1      109.99
# 9719   150498          27in FHD Monitor                 1      149.99
# 9720   150499           ThinkPad Laptop                 1      999.99
# 9721   150500    AAA Batteries (4-pack)                 2        2.99
# 9722   150501              Google Phone                 1      600.00
#
#           Order Date                       Purchase Address   sales  \
# ...

# %%
df["city"].value_counts()
# Out:
# San Francisco    2354
# Los Angeles      1529
# New York City    1303
# Boston           1048
# Atlanta           786
# Dallas            785
# Seattle           726
# Portland          623
# Austin            527
# Name: city, dtype: int64

# %%
df["city"].value_counts().index[:5]
# Out:
# Index(['San Francisco', 'Los Angeles', 'New York City', 'Boston', 'Atlanta'], dtype='object')

# %%
df["city"].value_counts().values[:5]
# Out:
# array([2354, 1529, 1303, 1048,  786], dtype=int64)

# %%
plt.figure(dpi=100,figsize=(6,6))
explode = [0.1, 0, 0, 0,0] 
plt.pie(df["city"].value_counts().values[:5],labels=df["city"].value_counts().index[:5],explode = explode,radius=0.6,autopct = '%1.f%%')
plt.title("Rich city")
plt.legend(loc=3)
plt.show()
